# %%
import pandas as pd
import numpy as np
data = pd.read_csv('https://raw.githubusercontent.com/TheUpshot/chipotle/master/orders.tsv', sep='\t')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
prices = []
price = data.item_price.values.tolist()
for item in price:
    prices.append(float(item[1:]))

for 

number_price = map(lambda x: float(x[1:]), price).sum()/

# %%
data['price_float'] = prices

# %%
orders = data.groupby('order_id')

# %%
round(orders.price_float.sum().mean(), 2)
# Out:
# 18.81

# %%
data.price_float.describe()
# Out:
# count    4622.000000
# mean        7.464336
# std         4.245557
# min         1.090000
# 25%         3.390000
# 50%         8.750000
# 75%         9.250000
# max        44.250000
# Name: price_float, dtype: float64

# %%
sodas = data.item_name[data.item_name.isin(['Canned Soda', 'Canned Soft Drinks'])].unique()

# %%
data[data.item_name.str.contains('Canned')].choice_description+data.choice_description
# Out:
# ['[Sprite]',
#  '[Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Diet Dr. Pepper]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Coke]',
#  '[Lemonade]',
#  '[Nestea]']

# %%
sodas = []
item_desc = data.loc[:,['item_name', 'choice_description']].values

# %%
for i in item_desc:
    if 'Canned' in i[0] and i[1] not in sodas:
        sodas.append(i[1])

# %%
sodas
# Out:
# ['[Sprite]',
#  '[Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Diet Dr. Pepper]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Coke]',
#  '[Lemonade]',
#  '[Nestea]']

# %%
u_sodas = []
# u_sodas = [i[1] for i in item_desc if ('Canned' in i[0]) and (i[1] not in u_sodas)]

# %%
u_sodas
# Out:
# ['[Sprite]',
#  '[Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Sprite]',
#  '[Dr. Pepper]',
#  '[Diet Dr. Pepper]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Diet Dr. Pepper]',
#  '[Coca Cola]',
#  '[Dr. Pepper]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Mountain Dew]',
#  '[Mountain Dew]',
#  '[Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Diet Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Coke]',
#  '[Coca Cola]',
#  '[Sprite]',
#  '[Diet Coke]',
#  '[Coke]',
#  '[Coke]',
#  '[Lemonade]',
#  '[Sprite]',
#  '[Diet Coke]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Mountain Dew]',
#  '[Coke]',
#  '[Coke]',
#  '[Coke]',
#  '[Sprite]',
#  '[Coke]',
#  '[Coke]',
#  '[Dr. Pepper]',
#  '[Coca Cola]',
#  '[Dr. Pepper]',
#  '[Coke]',
#  '[Diet Dr. Pepper]',
#  '[Diet Coke]',
#  '[Lemonade]',
#  '[Coke]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Nestea]',
#  '[Diet Coke]',
#  '[Dr. Pepper]',
#  '[Coke]',
#  '[Sprite]',
#  '[Coke]',
#  '[Lemonade]',
# ...
